# %%
import pandas as pd
import numpy as np

#Renaminc and combining

#Renaming

#rename() - change index names and/or column names

reviews.rename(columns={'points':'score'})
#output is original table with score instead of points

#specify whether you're changing index or column (index={} or columns={})

reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
#output table - only first two indexes renamed, rest remain numerical

#renaming index is rarer as set_index() is more convenient

#rename_axis() - change row index and column index name attribute

reviews.rename_axis('wines', axis='rows').rename_axis('fields, axis='columns)
#output table: 
#top row now 'fields' 'country' 'description' ... 'winery'
#aboxe index on separate row: 'wines'



#Combining

#concat(), join(), merge()
#most of merge() can be done using join()

#concat() - given list of elements, function will put them together along an axis
#useful if data in different dataframe or series objects but have same fields (columns)

#using different Youtube dataset-
canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
#output shows one table where data is either in canadian yt or british yt
#canadian/british yt are in different files/dataframes but have same columns so can be put together

#join() = combine different dataframe objects which have an index in common
#eg to get videos that were trending in both UK and Canada

left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
#lsuffix and rsuffix needed bc data has the same column names
#since the data would be the same, we only need one column
