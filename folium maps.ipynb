# %%
import folium
import math

map1 = folium.Map(location=[51.58221819463271, 0.0000789645876060591], zoom_start=14)

tooltip = 'Check out this place!'

folium.Marker([51.58325221590104, -0.019908802600608084], 
              popup="<b>Walthamstow Central Station</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="lightblue")
              ).add_to(map1)

folium.Marker([51.594910, -0.021052], 
              popup="<b>Lloyd's Park</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="green", icon='leaf')
              ).add_to(map1)

folium.Marker([51.56878598418458, 0.008736012313088739], 
              popup="<b>Leytonstone Station</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="lightblue")
              ).add_to(map1)

folium.Marker([51.57615280624766, 0.02865694570082124], 
              popup="<b>Wanstead Station</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="lightblue")
              ).add_to(map1)

folium.Marker([51.579043437015855, 0.010780817463375897], 
              popup="<b>Hollow Ponds</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="green", icon='leaf')
              ).add_to(map1)

folium.Marker([51.564138723024676, -0.02343983445160312], 
              popup="<b>Leyton Jubilee Park</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="green", icon='leaf')
              ).add_to(map1)

folium.Marker([51.582826257676, -0.00784103130468776], 
              popup="<b>Henry maynard Primary School</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="orange",  icon="pencil")
              ).add_to(map1)

folium.Marker([51.57806652147416, 0.0031712693741565577], 
              popup="<b>Whipps Cross Hospital</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="red",  icon="plus")
              ).add_to(map1)

folium.Marker([51.59230133828259, 0.02762896162298795], 
              popup="<b>South Woodford Station</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="lightblue")
              ).add_to(map1)

folium.Marker([51.587043607986416, -0.0408492068865889], 
              popup="<b>Blackhorse Road Station</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="lightblue")
              ).add_to(map1)

folium.Marker([51.58168991947722, -0.03214727252534987], 
              popup="<b>St James Street Station</b>", 
              tooltip=tooltip, 
              icon=folium.Icon(color="lightblue")
              ).add_to(map1)

folium.CircleMarker([51.58221819463271, 0.0000789645876060591], 
                    radius=500,  
                    color="red", 
                    fill=True, 
                    fill_color="lightred"
                    ).add_to(map1)

map1.add_child(folium.LatLngPopup())


map1
map1.save("walthamstow_map.html")
